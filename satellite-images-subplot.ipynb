# %% [markdown]
# <a href="https://colab.research.google.com/github/sajeebju/Visualization/blob/main/satellite-images-subplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt 
from PIL import Image
import matplotlib.image as mpimg
import cv2
import os
 

fig = plt.figure(figsize=(10, 10))
plt.subplots_adjust(wspace= 0.1, hspace= 0)

# Automobile image
ax1 = fig.add_subplot(2, 3, 1)
ax1.set_title("Automobile")
ax1.axis("off")
automobile_img = Image.open(os.path.join("/content/drive/MyDrive/satellite images/automobile.jpeg"))
ax1.imshow(automobile_img)

#Railway track track image
ax2 = fig.add_subplot(2, 3, 2)
ax2.set_title("Railway track")
ax2.axis("off")
railway_track_img = mpimg.imread(os.path.join("/content/drive/MyDrive/satellite images/railwaytrack.jpeg")) 
ax2.imshow(railway_track_img)

#BaseBall Court Image
ax3 = fig.add_subplot(2, 3, 3)
ax3.set_title("BaseBall Court ")
ax3.axis("off")
baseball_court_img = cv2.imread(os.path.join("/content/drive/MyDrive/satellite images/baseball.jpeg"))
ax3.imshow(baseball_court_img)

#Amazon Rain Forest Image
ax4 = fig.add_subplot(2, 3, 4)
ax4.set_title("Amazon Rain Forest")
ax4.axis("off")
amazon_img = cv2.imread(os.path.join("/content/drive/MyDrive/satellite images/amazon.jpeg"))
ax4.imshow(amazon_img)

#Swimming Pool Image
ax5 = fig.add_subplot(2, 3, 5)
ax5.set_title("Swimming Pool")
ax5.axis("off")      
swimming_pool_img = cv2.imread(os.path.join("/content/drive/MyDrive/satellite images/swimmingpool.jpeg"))
ax5.imshow(swimming_pool_img)

#Meandering River Image
ax6 = fig.add_subplot(2, 3, 6)
ax6.set_title("Meandering River") 
ax6.axis("off") 
meandering_river_image = Image.open(os.path.join("/content/drive/MyDrive/satellite images/meandering.jpeg"))
ax6.imshow(meandering_river_image)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   # Remove the CWD from sys.path while we load stuff.
